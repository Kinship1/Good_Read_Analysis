# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('good_reads_final.csv',parse_dates=['publish_date'])

# %%
df =df.drop_duplicates(['book_title'])
df.head()
# Out:
#    author_average_rating author_gender                          author_genres  \
# 0                   4.01        female                    historical-fiction,
# 1                   4.15          male  literature-fiction,mystery-thrillers,
# 2                   4.00        female                               romance,
# 3                   3.88          male                        fiction,memoir,
# 4                   4.10        female                   young-adult,fantasy,
#
#    author_id            author_name                           author_page_url  \
# 0      74489    Victoria Thompson\n      /author/show/74489.Victoria_Thompson
# 1     706255        Stieg Larsson\n         /author/show/706255.Stieg_Larsson
# 2    5618190  Mimi Jean Pamfiloff\n  /author/show/5618190.Mimi_Jean_Pamfiloff
# 3      37871          José Donoso\n             /author/show/37871.Jos_Donoso
# 4      36122    Patricia C. Wrede\n       /author/show/36122.Patricia_C_Wrede
#
# ...

# %%
cols = ['author_page_url','book_fullurl']      # list of uncessary columns to drop which do not concern our analysis
df.drop(columns=cols,inplace=True)             # both columns are dropped

# %%
df.head()                                      # to check our dataframe
# Out:
#    author_average_rating author_gender                          author_genres  \
# 0                   4.01        female                    historical-fiction,
# 1                   4.15          male  literature-fiction,mystery-thrillers,
# 2                   4.00        female                               romance,
# 3                   3.88          male                        fiction,memoir,
# 4                   4.10        female                   young-adult,fantasy,
#
#    author_id            author_name  author_rating_count  author_review_count  \
# 0      74489    Victoria Thompson\n                74399                 6268
# 1     706255        Stieg Larsson\n              3726435               142704
# 2    5618190  Mimi Jean Pamfiloff\n                76496                 7975
# 3      37871          José Donoso\n                 5522                  489
# 4      36122    Patricia C. Wrede\n               291013                13453
#
# ...

# %%
authors =df.drop_duplicates(['author_name'])
ay = authors['author_gender'].value_counts().plot(kind='bar',title='Total number of Male vs Female Authors')
ay.set_xlabel('Gender')
ay.set_ylabel('Count')
plt.show()

# %% [markdown]
# #### There are more male authors than their female counterparts

# %%
g1 = df['genre_1'].value_counts().head()
g2 = df['genre_2'].value_counts().head()

# %%
ay = g1.plot(kind='bar')
ay.set_xlabel('Genre 1')
ay.set_ylabel('No. of books')
ay.set_title('Top choice for Main Genre')
plt.show()

# %% [markdown]
# ### Authors prefer writing Fantasy and Romance books as the main genre of their book.

# %%
ay = g2.plot(kind='bar')
ay.set_xlabel('Genre 2')
ay.set_ylabel('No. of books')
ay.set_title('Top choice for side theme')
plt.show()

# %% [markdown]
# ### Authors prefer writing Romance and Fiction as the side plot of their books.

# %%
books = df.sort_values('num_ratings',ascending=False).head(10).set_index('book_title')
books.head()
# Out:
#                                   author_average_rating author_gender  \
# book_title
# \n      To Kill a Mockingbird\n                    4.22        female
# \n      The Great Gatsby\n                         3.89          male
# \n      The Fault in Our Stars\n                   4.07          male
# \n      Pride and Prejudice\n                      4.11        female
# 1984                                               4.05          male
#
#                                            author_genres  author_id  \
# book_title
# \n      To Kill a Mockingbird\n      literature-fiction,       1825
# \n      The Great Gatsby\n        fiction,short-stories,       3190
# \n      The Fault in Our Stars\n     literature-fiction,    1406384
# \n      Pride and Prejudice\n           fiction,romance,       1265
# 1984                                   fiction,politics,       3706
#
#                                             author_name  author_rating_count  \
# book_title
# ...

# %%
plt.subplots(figsize=(12,8))
ax = books['num_ratings'].sort_values().plot.barh(width=0.7,color=sns.color_palette('CMRmap',12),logx=True)
ax.set_xlabel("Total ratings count ", fontsize=15)
ax.set_ylabel("Books", fontsize=15)
ax.set_title("Top 10 most rated books",fontsize=20,color='black')
totals = []
for i in ax.patches:
    totals.append(i.get_width())
total = sum(totals)
for i in ax.patches:
    ax.text(i.get_width()+3, i.get_y()+.2,str(round(i.get_width())), fontsize=15,color='black')
plt.show()

# %%
authors['author_average_rating'].sort_values().plot(kind='bar')
plt.show()

# %%
high_rated_author = df[df['book_average_rating']>=4.3]
high_rated_author = high_rated_author.groupby('author_name')['book_title'].count().reset_index().sort_values('book_title', ascending = False).head(10).set_index('author_name')
plt.figure(figsize=(15,10))
ax = sns.barplot(high_rated_author['book_title'], high_rated_author.index, palette='Set2')
ax.set_xlabel("Number of Books")
ax.set_ylabel("Authors")
for i in ax.patches:
    ax.text(i.get_width()+.3, i.get_y()+0.5, str(round(i.get_width())), fontsize = 10, color = 'k')

# %%
df.head()
# Out:
#    author_average_rating author_gender                          author_genres  \
# 0                   4.01        female                    historical-fiction,
# 1                   4.15          male  literature-fiction,mystery-thrillers,
# 2                   4.00        female                               romance,
# 3                   3.88          male                        fiction,memoir,
# 4                   4.10        female                   young-adult,fantasy,
#
#    author_id            author_name  author_rating_count  author_review_count  \
# 0      74489    Victoria Thompson\n                74399                 6268
# 1     706255        Stieg Larsson\n              3726435               142704
# 2    5618190  Mimi Jean Pamfiloff\n                76496                 7975
# 3      37871          José Donoso\n                 5522                  489
# 4      36122    Patricia C. Wrede\n               291013                13453
#
# ...

# %%
birthplace = df['birthplace'].value_counts()
k = birthplace.drop(labels=['\n  ','\n  \n    '])
#k.head(10)
plt.figure(figsize=(15,10))
k.head(10).plot(kind='bar')
plt.show()

# %%
df['birthplace'] = df['birthplace'].astype('|S')

# %%
 df['birthplace'].value_counts()
# Out:
# b'\n  '                                 3022
# b' United States\n  '                   2714
# b'\n   United States\n  '               2489
# b' United States\n    '                 2377
# b' United Kingdom\n    '                 682
# b' United Kingdom\n  '                   480
# b'\n   United States\n    '              477
# b'\n   United Kingdom\n  '               309
# b'\n  \n    '                            295
# b'Canada\n  '                            185
# b'\n  Canada\n  '                        166
# b'Japan\n    '                           158
# b'Germany\n    '                         114
# b'Egypt\n    '                           104
# b'Australia\n  '                         103
# b'Canada\n    '                          103
# b'\n  Australia\n  '                     101
# b'India\n    '                            87
# b'France\n    '                           87
# b'Ireland\n    '                          86
# b'\n   United Kingdom\n    '              85
# ...

# %%
def plotPerColumnDistribution(df, nGraphShown, nGraphPerRow):
    nunique = df.nunique()
    df = df[[col for col in df if nunique[col] > 1 and nunique[col] < 50]] # For displaying purposes, pick columns that have between 1 and 50 unique values
    nRow, nCol = df.shape
    columnNames = list(df)
    nGraphRow = (nCol + nGraphPerRow - 1) / nGraphPerRow
    plt.figure(num = None, figsize = (6 * nGraphPerRow, 8 * nGraphRow), dpi = 80, facecolor = 'w', edgecolor = 'k')
    for i in range(min(nCol, nGraphShown)):
        plt.subplot(nGraphRow, nGraphPerRow, i + 1)
        columnDf = df.iloc[:, i]
        if (not np.issubdtype(type(columnDf.iloc[0]), np.number)):
            valueCounts = columnDf.value_counts()
            valueCounts.plot.bar()
        else:
            columnDf.hist()
        plt.ylabel('counts')
        plt.xticks(rotation = 90)
        plt.title(f'{columnNames[i]} (column {i})')
    plt.tight_layout(pad = 1.0, w_pad = 1.0, h_pad = 1.0)
    plt.show()
df1 = pd.read_csv('good_reads_final.csv', delimiter=',', nrows = None)
plotPerColumnDistribution(df1, 10, 5)
